# %%
#fastai study group.  learning my way around Kaggle.  Not competing yet.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lish-moa/train_targets_scored.csv
# /kaggle/input/lish-moa/train_drug.csv
# /kaggle/input/lish-moa/train_targets_nonscored.csv
# /kaggle/input/lish-moa/train_features.csv
# /kaggle/input/lish-moa/sample_submission.csv
# /kaggle/input/lish-moa/test_features.csv

# %%
from fastai.tabular.all import *
path = Path('../input/lish-moa')
path.ls()
# Out:
# (#6) [Path('../input/lish-moa/train_targets_scored.csv'),Path('../input/lish-moa/train_drug.csv'),Path('../input/lish-moa/train_targets_nonscored.csv'),Path('../input/lish-moa/train_features.csv'),Path('../input/lish-moa/sample_submission.csv'),Path('../input/lish-moa/test_features.csv')]

# %%
train_drugs = pd.read_csv(path/'train_drug.csv')
train_features = pd.read_csv('/kaggle/input/lish-moa/train_features.csv')
train_targets_scored = pd.read_csv('/kaggle/input/lish-moa/train_targets_scored.csv')
train_targets_nonscored = pd.read_csv('/kaggle/input/lish-moa/train_targets_nonscored.csv')
test_features = pd.read_csv('/kaggle/input/lish-moa/test_features.csv')
sub = pd.read_csv('/kaggle/input/lish-moa/sample_submission.csv')

# %%
print('Dataset sizes:  \ntrain drugs', train_drugs.shape)
print('train features', train_features.shape)
print('train targets', train_targets_scored.shape)
print('test features', test_features.shape)

display(train_features.head(3))
display(train_targets_scored.head(3))
# Out:
# Dataset sizes:
# train drugs (23814, 2)
# train features (23814, 876)
# train targets (23814, 207)
# test features (3982, 876)
#          sig_id cp_type  cp_time cp_dose     g-0     g-1     g-2     g-3  \
# 0  id_000644bb2  trt_cp       24      D1  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  trt_cp       72      D1  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  trt_cp       48      D1  0.6280  0.5817  1.5540 -0.0764
#
#       g-4     g-5  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.1944 -1.0120  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  1.0190  0.5207  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0323  1.2390  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# 1  0.1522  0.1241  0.6077  0.7371
# 2 -0.6417 -0.2187 -1.4080  0.6931
#
# [3 rows x 876 columns]
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# ...

# %%
train_drugs.describe()
# Out:
#               sig_id    drug_id
# count          23814      23814
# unique         23814       3289
# top     id_94a826b7c  cacb2b860
# freq               1       1866

# %%
##save before changing?
#train_features_original = train_features.copy()

# %% [markdown]
# ## 1. Data Prep
# - Categorical features: `cp_type`,`cp_time`,`cp_dose`
# - Combine features and targets
#
# todo: explore drugs and features
# todo: remove control records from training

# %%
#handle categorical features: ordinal only
cp_time = np.sort(train_features['cp_time'].unique()) #numpy.ndarray [24,48,72]

train_features['cp_time'] = train_features['cp_time'].astype('category')
train_features['cp_time'].cat.set_categories(cp_time, ordered=True, inplace=True)
print("ordinal: ", train_features['cp_time'].unique())

test_features['cp_time'] = test_features['cp_time'].astype('category')
test_features['cp_time'].cat.set_categories(cp_time, ordered=True, inplace=True)
print("ordinal: ", test_features['cp_time'].unique())
# Out:
# ordinal:  [24, 72, 48]
# Categories (3, int64): [24 < 48 < 72]
# ordinal:  [24, 72, 48]
# Categories (3, int64): [24 < 48 < 72]

# %%
train_features.shape, train_targets_scored.shape #$actomatch
# Out:
# ((23814, 876), (23814, 207))

# %%
#combine features and targets
dep_var = [i for i in train_targets_scored.columns if i != 'sig_id']
train_features[dep_var] = train_targets_scored[dep_var]
print(train_features.shape)

#preview results - appended targets
train_features.iloc[1:5,-5:-1]
# Out:
# (23814, 1082)
#    ubiquitin_specific_protease_inhibitor  vegfr_inhibitor  vitamin_b  \
# 1                                      0                0          0
# 2                                      0                0          0
# 3                                      0                0          0
# 4                                      0                0          0
#
#    vitamin_d_receptor_agonist
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
# We have appended the targets to the features dataframe
train_features.iloc[1:5,-5:-1]
# Out:
#    ubiquitin_specific_protease_inhibitor  vegfr_inhibitor  vitamin_b  \
# 1                                      0                0          0
# 2                                      0                0          0
# 3                                      0                0          0
# 4                                      0                0          0
#
#    vitamin_d_receptor_agonist
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
#don't train on control records
#EDA finding all drugs cacb2b860 being ctl_vehicle

train_features = train_features[train_features['cp_type'] != 'ctl_vehicle'].copy()
train_features.shape
# Out:
# (21948, 1082)

# %% [markdown]
# ## 2. Model Prep
# ##### Using TabularPandas and TabularProc

# %%
##error: NameError: name 'RandomSplitter' is not defined
#splits = RandomSplitter(valid_pct=0.2)(range_of(train_features))
#splits

#temp split manually
#define train vs valid split
n_train = int(train_features.shape[0] *.8)
split_idx = np.random.RandomState(seed=24).permutation(train_features.shape[0])
train_idx, test_idx = split_idx[:n_train], split_idx[n_train:]
splits = (list(train_idx), list(test_idx))

#preview
len(splits[0]), len(splits[1])
# Out:
# (17558, 4390)

# %%
procs = [FillMissing,Categorify,Normalize]

# %%
cont_features,cat_features = cont_cat_split(train_features, dep_var=dep_var) 

#if need to remove a field
cat_features.remove('sig_id')

#mycheck
cat_features, cont_features
# Out:
# (['cp_type', 'cp_time', 'cp_dose'],
#  ['g-0',
#   'g-1',
#   'g-2',
#   'g-3',
#   'g-4',
#   'g-5',
#   'g-6',
#   'g-7',
#   'g-8',
#   'g-9',
#   'g-10',
#   'g-11',
#   'g-12',
#   'g-13',
#   'g-14',
#   'g-15',
#   'g-16',
#   'g-17',
#   'g-18',
#   'g-19',
#   'g-20',
#   'g-21',
#   'g-22',
#   'g-23',
#   'g-24',
#   'g-25',
#   'g-26',
#   'g-27',
#   'g-28',
#   'g-29',
#   'g-30',
#   'g-31',
#   'g-32',
#   'g-33',
#   'g-34',
#   'g-35',
#   'g-36',
#   'g-37',
#   'g-38',
#   'g-39',
#   'g-40',
#   'g-41',
#   'g-42',
#   'g-43',
#   'g-44',
#   'g-45',
#   'g-46',
#   'g-47',
#   'g-48',
#   'g-49',
#   'g-50',
#   'g-51',
#   'g-52',
#   'g-53',
#   'g-54',
#   'g-55',
#   'g-56',
#   'g-57',
#   'g-58',
#   'g-59',
#   'g-60',
#   'g-61',
#   'g-62',
#   'g-63',
#   'g-64',
#   'g-65',
#   'g-66',
#   'g-67',
#   'g-68',
#   'g-69',
#   'g-70',
#   'g-71',
#   'g-72',
#   'g-73',
#   'g-74',
#   'g-75',
#   'g-76',
#   'g-77',
#   'g-78',
#   'g-79',
#   'g-80',
# ...

# %%
to = TabularPandas(train_features, procs=procs, cat_names=cat_features, cont_names=cont_features, 
                   splits = splits, y_names = dep_var)

# %%
#confirm cats
train_features[cat_features].nunique()
# Out:
# cp_type    1
# cp_time    3
# cp_dose    2
# dtype: int64

# %%
len(to.train), len(to.valid)
# Out:
# (17558, 4390)

# %%
to.show(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cp_type</th>
#       <th>cp_time</th>
#       <th>cp_dose</th>
#       <th>g-0</th>
#       <th>g-1</th>
#       <th>g-2</th>
#       <th>g-3</th>
#       <th>g-4</th>
#       <th>g-5</th>
#       <th>g-6</th>
#       <th>g-7</th>
#       <th>g-8</th>
#       <th>g-9</th>
#       <th>g-10</th>
#       <th>g-11</th>
#       <th>g-12</th>
#       <th>g-13</th>
#       <th>g-14</th>
#       <th>g-15</th>
#       <th>g-16</th>
#       <th>g-17</th>
#       <th>g-18</th>
#       <th>g-19</th>
#       <th>g-20</th>
#       <th>g-21</th>
#       <th>g-22</th>
#       <th>g-23</th>
#       <th>g-24</th>
#       <th>g-25</th>
#       <th>g-26</th>
#       <th>g-27</th>
#       <th>g-28</th>
#       <th>g-29</th>
#       <th>g-30</th>
#       <th>g-31</th>
#       <th>g-32</th>
#       <th>g-33</th>
#       <th>g-34</th>
#       <th>g-35</th>
#       <th>g-36</th>
# ...

# %%
#data loaders 
dls = to.dataloaders(1024) #hyperparam 512

# %%
#setup learner
learn = tabular_learner(dls, layers=[300, 200]) #hyperparms , loss_func=BCEWithLogitsLossFlat()

# %%
learn.loss_func
# Out:
# FlattenedLoss of MSELoss()

# %%
#find learing rate
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.002754228748381138, lr_steep=0.0831763744354248)

# %%
#learn.fit_one_cycle(8,3.31E-02) #$was 1e-2
learn.fit_one_cycle(8,3.3E-02)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.014427</td>
#       <td>0.009215</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.009019</td>
#       <td>0.003995</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.006615</td>
#       <td>0.003710</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.005457</td>
#       <td>0.003683</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.004802</td>
#       <td>0.003648</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.004396</td>
#       <td>0.003632</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.004132</td>
# ...

# %%
learn.recorder.plot_loss()

# %%
learn.unfreeze()
learn.fit_one_cycle(5,slice(1e-04),wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.003579</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.003575</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003571</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003569</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.003568</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(1e-5),wd=0.25)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.003569</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.003568</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003568</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003567</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.003565</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
learn.unfreeze()
learn.fit_one_cycle(5, slice(1e-6),wd=0.4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.003563</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.003566</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.003564</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.003565</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.003566</td>
#       <td>0.003624</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %% [markdown]
# ## 3. Predict

# %%
#Get Predictions for Submission
#We follow the guide to setting up a test set here: https://forums.fast.ai/t/a-brief-guide-to-test-sets-in-v2-you-can-do-labelled-now-too/57054
#testset
test_features.shape
# Out:
# (3982, 876)

# %%
#Get Predictions for Submission
#We follow the guide to setting up a test set here: https://forums.fast.ai/t/a-brief-guide-to-test-sets-in-v2-you-can-do-labelled-now-too/57054
#testset
test_dl = dls.test_dl(test_features)

# %%
test_dl.show(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cp_type</th>
#       <th>cp_time</th>
#       <th>cp_dose</th>
#       <th>g-0</th>
#       <th>g-1</th>
#       <th>g-2</th>
#       <th>g-3</th>
#       <th>g-4</th>
#       <th>g-5</th>
#       <th>g-6</th>
#       <th>g-7</th>
#       <th>g-8</th>
#       <th>g-9</th>
#       <th>g-10</th>
#       <th>g-11</th>
#       <th>g-12</th>
#       <th>g-13</th>
#       <th>g-14</th>
#       <th>g-15</th>
#       <th>g-16</th>
#       <th>g-17</th>
#       <th>g-18</th>
#       <th>g-19</th>
#       <th>g-20</th>
#       <th>g-21</th>
#       <th>g-22</th>
#       <th>g-23</th>
#       <th>g-24</th>
#       <th>g-25</th>
#       <th>g-26</th>
#       <th>g-27</th>
#       <th>g-28</th>
#       <th>g-29</th>
#       <th>g-30</th>
#       <th>g-31</th>
#       <th>g-32</th>
#       <th>g-33</th>
#       <th>g-34</th>
#       <th>g-35</th>
#       <th>g-36</th>
# ...

# %%
preds,_ = learn.get_preds(dl=test_dl)

# %%
preds_df = pd.DataFrame(preds).astype("float")

# %%
preds_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.000698  0.000616  0.001266  0.008555  0.013581  0.003487  0.002365
# 1  0.000698  0.000616  0.001266  0.008555  0.013581  0.003487  0.002365
# 2  0.000551  0.000812  0.001201  0.008307  0.013597  0.003476  0.002785
# 3  0.000698  0.000616  0.001266  0.008555  0.013581  0.003487  0.002365
# 4  0.000698  0.000616  0.001266  0.008555  0.013581  0.003487  0.002365
#
#         7         8         9    ...       196       197       198       199  \
# 0  0.004279  0.000558  0.012932  ... -0.000106  0.001236  0.002120  0.004067
# 1  0.004279  0.000558  0.012932  ... -0.000106  0.001236  0.002120  0.004067
# 2  0.004158  0.000328  0.011949  ...  0.000636  0.001108  0.002512  0.019666
# 3  0.004279  0.000558  0.012932  ... -0.000106  0.001236  0.002120  0.004067
# 4  0.004279  0.000558  0.012932  ... -0.000106  0.001236  0.002120  0.004067
#
#         200       201       202       203       204       205
# ...

# %%
submission = sub
submission[dep_var] = preds_df
submission.loc[test_features['cp_type']=='ctl_vehicle', dep_var] = 0

# %%
submission.head()
# Out:
#          sig_id  5-alpha_reductase_inhibitor  11-beta-hsd1_inhibitor  \
# 0  id_0004d9e33                     0.000698                0.000616
# 1  id_001897cda                     0.000698                0.000616
# 2  id_002429b5b                     0.000000                0.000000
# 3  id_00276f245                     0.000698                0.000616
# 4  id_0027f1083                     0.000698                0.000616
#
#    acat_inhibitor  acetylcholine_receptor_agonist  \
# 0        0.001266                        0.008555
# 1        0.001266                        0.008555
# 2        0.000000                        0.000000
# 3        0.001266                        0.008555
# 4        0.001266                        0.008555
#
#    acetylcholine_receptor_antagonist  acetylcholinesterase_inhibitor  \
# 0                           0.013581                        0.003487
# 1                           0.013581                        0.003487
# ...

# %%
submission.to_csv('submission.csv', index=False)
